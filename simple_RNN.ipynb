# %%
#import lib พื้นฐานที่จำเป็น
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter("ignore") # เอาไว้ ลบwarning

# %%
#import dataset และ print เช็คข้อมูล
data = pd.read_csv("data.csv")
data.head()
# Out:
#          Id                                              Title  \
# 0  34552656             Java: Repeat Task Every Random Seconds
# 1  34553034                  Why are Java Optionals immutable?
# 2  34553174  Text Overlay Image with Darkened Opacity React...
# 3  34553318         Why ternary operator in swift is so picky?
# 4  34553755                 hide/show fab with scale animation
#
#                                                 Body  \
# 0  <p>I'm already familiar with repeating tasks e...
# 1  <p>I'd like to understand why Java 8 Optionals...
# 2  <p>I am attempting to overlay a title over an ...
# 3  <p>The question is very simple, but I just cou...
# 4  <p>I'm using custom floatingactionmenu. I need...
#
#                                                 Tags         CreationDate  \
# 0                                     <java><repeat>  2016-01-01 00:21:59
# 1                                   <java><optional>  2016-01-01 02:03:20
# 2  <javascript><overlay><react-native><opa...  2016-01-01 02:48:24
# 3  <swift><operators><whitespace><ternary-operato...  2016-01-01 03:30:17
# 4  <android><material-design><floating-action-but...  2016-01-01 05:21:48
#
#           Y
# 0  LQ_CLOSE
# 1        HQ
# 2        HQ
# 3        HQ
# 4        HQ

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            45000 non-null  int64
#  1   Title         45000 non-null  object
#  2   Body          45000 non-null  object
#  3   Tags          45000 non-null  object
#  4   CreationDate  45000 non-null  object
#  5   Y             45000 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.1+ MB

# %%
#ตัด feature ใน dataset ที่ไม่จำเป็นออกไป
data = data.drop(['Id' , 'Tags' , 'CreationDate'],axis=1) # ลบ feature ที่ไม่สำคัญออกไป
data['Y'] = data['Y'].map({'LQ_CLOSE':0,'LQ_EDIT':1,'HQ':2}) # encoded target class ใหม่ให้กลายเป็นตัวเลข ตามลำดับ

data.head()
# Out:
#                                                Title  \
# 0             Java: Repeat Task Every Random Seconds
# 1                  Why are Java Optionals immutable?
# 2  Text Overlay Image with Darkened Opacity React...
# 3         Why ternary operator in swift is so picky?
# 4                 hide/show fab with scale animation
#
#                                                 Body  Y
# 0  <p>I'm already familiar with repeating tasks e...  0
# 1  <p>I'd like to understand why Java 8 Optionals...  2
# 2  <p>I am attempting to overlay a title over an ...  2
# 3  <p>The question is very simple, but I just cou...  2
# 4  <p>I'm using custom floatingactionmenu. I need...  2

# %%
data['text'] = data['Title'] + ' ' + data['Body'] # รวม Title และ Body เข้าด้วยกันเพื่อเตรียมไปใส่ในmodel และเปลี่ยนชื่อเป็น text
data = data.drop(['Title','Body'],axis=1) # ทิ้งอันเดิม ออก
data.head()
# Out:
#    Y                                               text
# 0  0  Java: Repeat Task Every Random Seconds <p>I'm ...
# 1  2  Why are Java Optionals immutable? <p>I'd like ...
# 2  2  Text Overlay Image with Darkened Opacity React...
# 3  2  Why ternary operator in swift is so picky? <p>...
# 4  2  hide/show fab with scale animation <p>I'm usin...

# %%
import re # import regularexpression
def clean(text): # ฟังก์ชั่น ลบเครื่องหมายต่างๆ ที่ไม่ใช่text ออก เช่น? <> โดยใช้ regular expression
    text = text.lower() # เปลี่ยนให้เป็น lower case
    text = re.sub(r'[^(a-zA-Z)\s]','',text)
    return text

# %%
data['text'] = data['text'].apply(clean) # เรียกใช้ ฟังก์ชั่น clean

data.head()
# Out:
#    Y                                               text
# 0  0  java repeat task every random seconds pim alre...
# 1  2  why are java optionals immutable pid like to u...
# 2  2  text overlay image with darkened opacity react...
# 3  2  why ternary operator in swift is so picky pthe...
# 4  2  hideshow fab with scale animation pim using cu...

# %% [markdown]
# ### สร้างvector ของข้อมูล โดยเลือกใช้ Word tokenized

# %%
X = data['text'].values # แยก feature กับ target class ออกจากกัน
y = data['Y'].values

# %%
def plot_history(model): # ฟังก์ชั่นสำหรับใช้ plot graph วัดประสิทธิภาพโมเดล
    acc = model.history['accuracy']
    val_acc = model.history['val_accuracy']
    loss = model.history['loss']
    val_loss = model.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training acc')
    plt.plot(x, val_acc, 'r', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training loss')
    plt.plot(x, val_loss, 'r', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

# %% [markdown]
# ### สร้าง simple RNN model

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding

tokenizer = Tokenizer(num_words=500) # ลองเปลี่ยนเลขได้ แต่ค่าที่เหมาะที่สุดตอนนี้คือ 500 แต่ลองปรับให้ลดลง
tokenizer.fit_on_texts(X)
vocab = tokenizer.word_index

# %%
X_tokenized = tokenizer.texts_to_sequences(X)
#max_seq_length = max(len(seq) for seq in X_tokenized)
X_padded = pad_sequences(X_tokenized, maxlen=100, padding='post', truncating='post') # สามารถเปลี่ยน maxlen ได้ แต่ค่าที่น่าจะเหมาะสมที่สุดคือ 100

# %% [markdown]
# ในการทำ word embeding จะเลือกใช้วิธี wordTokenized โดยการตั้งให้จำนวน numword = 500 เพราะอยากลองจำนวน numword เพราะเป็นค่าที่ให้ผลดีที่สุดใน 4 model ที่ผ่านมา
#
#
# ส่วนในการ padding จะเลือกใช้ แค่ 100 เพราะค่าอื่นๆมันมากเกินไปและไม่มีความจำเป็นต่อการ train  แต่ก็สามารถเพิ่มหรือลดได้ถ้าต้องการ

# %%
import matplotlib.pyplot as plt #กราฟสำหรับโชว์ว่า ควรตั้ง max สำหรับการ pad เท่าไหร่

# Plot histogram
plt.hist([len(seq) for seq in X_tokenized], bins=30)
plt.xlabel('Sequence Length')
plt.ylabel('Frequency')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.3, random_state=42) #แบ่งเป็น 70/30

# %%
X_test.shape
# Out:
# (13500, 100)

# %%
# ถ้าเคย train model ด้วย model.fit แล้วต้องการรันใหม่อีกครั้งให้เคลียร์ค่า weight เก่าก่อน 
# ถ้าไม่เคลียร์ค่า weight เก่า จะทำการ train ต่อจากครั้งล่าสุด

from keras.backend import clear_session
clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

model = Sequential()
model.add(Embedding(input_dim=500, output_dim=30, input_length=100)) 
model.add(Dropout(0.3)) #dropout layers
model.add(LSTM(units=5))
model.add(Dropout(0.3)) #dropout layers
model.add(Dense(units=3, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 30)           15000
#
#  dropout (Dropout)           (None, 100, 30)           0
#
#  lstm (LSTM)                 (None, 5)                 720
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense (Dense)               (None, 3)                 18
#
# =================================================================
# Total params: 15738 (61.48 KB)
# Trainable params: 15738 (61.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ในการสร้าง simple RNN model ด้วยการใช้ embedding layer  จะประกอบไปด้วย
#
# layer1
#
# เป็น embedding layer ที่จะมี input อยู่ที่ 500 (อิงตามจำนวน word) output ที่30 และ input_length ที่ 100 (อิงตามการ padding)
#
# dropout
#
# เป็น regularization เพื่อลด overfit โดยตั้ง droprate ที่ 30%
#
# LSTM layer
#
# ทำหน้าที่จับ ความสำคัญของข้อมูล ในเวลาก่อนๆมาใช้ร่วมกับข้อมูล ณ เวลาปัจุบัน โดยจะตั้ง output space = 5 (unit) เนื่องจาก dataset ไม่จำเป็นต้องใช้จำนวนข้อมูลซํบซ้อนมากขนาดนั้น
#
# dropout
#
# เป็น regularization เพื่อลด overfit โดยตั้ง droprate ที่ 30%
#
# output layers
#
# เป็น output ที่ตั้งตามจำนวนclass และใช้ softmax สำหรับการกระจายความน่าจะเป็นของข้อมูลออกตอน predict โดยตั้ง units 3 ตามจำนวน target class

# %% [markdown]
# ### ในส่วน compile
# loss = sparse_categorical_crossentropy = เอาไว้ใช้กับกรณี muticlassification (dataset ตัวนี้มี target 3 ตัว) ที่จะคำนวณค่าต่างๆออกมาเป็น ความน่าจะเป็นต่างๆแล้วนำไปเปรียบเทียบกับ กับค่าที่เป็น true
#
# metric = accuracy = เป็นคะแนนที่เอาไว้บอกว่า model มีความสามารถในการ predict ออกมาได้ตรงมากขนาดไหน
#
# adam = ใส่ไว้เป็นตัวลด loss เวลาที่ model กำลัง train อยู่

# %% [markdown]
# ### การคำนวณparam ต่างๆ
# โดย shape ของ X_train เราจะ เป็น (31500, 100)
#
# embedding layer
#
# คำนวณได้จาก input*output  = 500 * 30 = 15000 parameter (รวม weigth และ bias ทั้งหมดแล้ว)
#
# dropout layer
#
# ไม่มี การเพิ่มใดๆ เพียงแค่เป็นการลด overfit เท่านั้น
#
# lstm layer
#
# คำนวณได้จากสูตร 4*((input_dim+1) * units + units^2) = 4 * ((31+1) * 5 + 5^2) = 720 parameters
#
# จากการที่เรามี 5 unit ใน lstm ผลรวมทั้งหมดของ param ใน lstm layer จะเป็น = 5*720 = 3600 parameters
#
# dropout layer
#
# ไม่มี การเพิ่มใดๆ เพียงแค่เป็นการลด overfit เท่านั้น
#
# output layers
#
# คำนวณได้จาก input*units+units = 5*3+3 =18
#
#
#
# ### รวม parameter ทั้งหมดจะได้ 15000 + 720 + 18 = 15738 parameters

# %%
#fuction สำหรับการ insert รูปภาพลง jupyter notebook
import base64
from IPython.display import HTML

image_path = 'RNNMODEL.jpg'

with open(image_path, 'rb') as f:
    image_data = base64.b64encode(f.read()).decode('utf-8')

html_code = f'<img src="data:image/jpeg;base64,{image_data}" width="600" height="750">'
HTML(html_code)
# Out:
# <img src="data:image/jpeg;base64,..." width="600" height="750">

# %%
from keras.callbacks import EarlyStopping

# Early stopping เพื่อลด overfit ในกรณีloss เด้งขึ้นมา และจะตัดรอบ กรณีถ้าไม่ดีขค้นภายใน15รอบ
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# %%
simple = model.fit(
    X_train, y_train,
    epochs=50, # ทำ50รอบ
    batch_size=10, # สามารถลดได้ ถ้าอยาก generalize ข้อมูลและขึ้นอยู่กับเครื่อง
    validation_data=(X_test, y_test),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# 3150/3150 [==============================] - 43s 13ms/step - loss: 0.7400 - accuracy: 0.6020 - val_loss: 0.6441 - val_accuracy: 0.6276
# Epoch 2/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.6992 - accuracy: 0.6310 - val_loss: 0.6284 - val_accuracy: 0.6629
# Epoch 3/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.6481 - accuracy: 0.6508 - val_loss: 0.6067 - val_accuracy: 0.6703
# Epoch 4/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.6389 - accuracy: 0.6528 - val_loss: 0.6175 - val_accuracy: 0.6666
# Epoch 5/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.6374 - accuracy: 0.6653 - val_loss: 0.6030 - val_accuracy: 0.7110
# Epoch 6/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.5822 - accuracy: 0.7313 - val_loss: 0.5168 - val_accuracy: 0.8029
# Epoch 7/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.6122 - accuracy: 0.7487 - val_loss: 0.5139 - val_accuracy: 0.8094
# Epoch 8/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.5740 - accuracy: 0.7601 - val_loss: 0.4941 - val_accuracy: 0.8112
# Epoch 9/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.5552 - accuracy: 0.7797 - val_loss: 0.4908 - val_accuracy: 0.8207
# Epoch 10/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.5329 - accuracy: 0.7930 - val_loss: 0.4865 - val_accuracy: 0.8147
# Epoch 11/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.5420 - accuracy: 0.7863 - val_loss: 0.4663 - val_accuracy: 0.8256
# Epoch 12/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.5117 - accuracy: 0.8086 - val_loss: 0.4509 - val_accuracy: 0.8326
# Epoch 13/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.5025 - accuracy: 0.8173 - val_loss: 0.4652 - val_accuracy: 0.8300
# Epoch 14/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4814 - accuracy: 0.8255 - val_loss: 0.4224 - val_accuracy: 0.8387
# Epoch 15/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4678 - accuracy: 0.8250 - val_loss: 0.4591 - val_accuracy: 0.8350
# Epoch 16/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4566 - accuracy: 0.8308 - val_loss: 0.3946 - val_accuracy: 0.8424
# Epoch 17/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4376 - accuracy: 0.8271 - val_loss: 0.3793 - val_accuracy: 0.8414
# Epoch 18/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4210 - accuracy: 0.8294 - val_loss: 0.3794 - val_accuracy: 0.8441
# Epoch 19/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4231 - accuracy: 0.8303 - val_loss: 0.3705 - val_accuracy: 0.8458
# Epoch 20/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.4024 - accuracy: 0.8358 - val_loss: 0.3513 - val_accuracy: 0.8521
# Epoch 21/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.3837 - accuracy: 0.8356 - val_loss: 0.3430 - val_accuracy: 0.8544
# Epoch 22/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.3748 - accuracy: 0.8379 - val_loss: 0.3309 - val_accuracy: 0.8582
# Epoch 23/50
# 3150/3150 [==============================] - 38s 12ms/step - loss: 0.3695 - accuracy: 0.8374 - val_loss: 0.3259 - val_accuracy: 0.8617
# Epoch 24/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3595 - accuracy: 0.8419 - val_loss: 0.3220 - val_accuracy: 0.8605
# Epoch 25/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3565 - accuracy: 0.8410 - val_loss: 0.3205 - val_accuracy: 0.8630
# Epoch 26/50
# 3150/3150 [==============================] - 39s 13ms/step - loss: 0.3573 - accuracy: 0.8410 - val_loss: 0.3176 - val_accuracy: 0.8652
# Epoch 27/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3505 - accuracy: 0.8434 - val_loss: 0.3153 - val_accuracy: 0.8647
# Epoch 28/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3470 - accuracy: 0.8437 - val_loss: 0.3145 - val_accuracy: 0.8641
# Epoch 29/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3431 - accuracy: 0.8466 - val_loss: 0.3331 - val_accuracy: 0.8569
# Epoch 30/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3427 - accuracy: 0.8479 - val_loss: 0.3324 - val_accuracy: 0.8619
# Epoch 31/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3417 - accuracy: 0.8463 - val_loss: 0.3179 - val_accuracy: 0.8609
# Epoch 32/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3353 - accuracy: 0.8517 - val_loss: 0.3149 - val_accuracy: 0.8615
# Epoch 33/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3332 - accuracy: 0.8541 - val_loss: 0.3211 - val_accuracy: 0.8644
# Epoch 34/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3374 - accuracy: 0.8504 - val_loss: 0.3186 - val_accuracy: 0.8592
# Epoch 35/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3343 - accuracy: 0.8548 - val_loss: 0.3214 - val_accuracy: 0.8633
# Epoch 36/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3360 - accuracy: 0.8515 - val_loss: 0.3204 - val_accuracy: 0.8627
# Epoch 37/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3261 - accuracy: 0.8576 - val_loss: 0.3114 - val_accuracy: 0.8640
# Epoch 38/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3247 - accuracy: 0.8588 - val_loss: 0.3230 - val_accuracy: 0.8545
# Epoch 39/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3290 - accuracy: 0.8542 - val_loss: 0.3339 - val_accuracy: 0.8614
# Epoch 40/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3249 - accuracy: 0.8587 - val_loss: 0.3278 - val_accuracy: 0.8570
# Epoch 41/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3260 - accuracy: 0.8578 - val_loss: 0.3154 - val_accuracy: 0.8621
# Epoch 42/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3238 - accuracy: 0.8620 - val_loss: 0.3185 - val_accuracy: 0.8589
# Epoch 43/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3200 - accuracy: 0.8629 - val_loss: 0.3293 - val_accuracy: 0.8633
# Epoch 44/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3192 - accuracy: 0.8620 - val_loss: 0.3229 - val_accuracy: 0.8639
# Epoch 45/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3197 - accuracy: 0.8611 - val_loss: 0.3225 - val_accuracy: 0.8637
# Epoch 46/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3194 - accuracy: 0.8607 - val_loss: 0.3174 - val_accuracy: 0.8650
# Epoch 47/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3156 - accuracy: 0.8628 - val_loss: 0.3324 - val_accuracy: 0.8557
# Epoch 48/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3151 - accuracy: 0.8679 - val_loss: 0.3394 - val_accuracy: 0.8639
# Epoch 49/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3147 - accuracy: 0.8659 - val_loss: 0.3233 - val_accuracy: 0.8638
# Epoch 50/50
# 3150/3150 [==============================] - 37s 12ms/step - loss: 0.3155 - accuracy: 0.8648 - val_loss: 0.3252 - val_accuracy: 0.8673

# %%
plot_history(simple)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix,accuracy_score

y_pred = model.predict(X_test)
# Out:
# 422/422 [==============================] - 2s 6ms/step

# %%
y_pred_classes = np.argmax(y_pred, axis=1)

# %%
cm = confusion_matrix(y_test, y_pred_classes)
# Out:
# array([[3463,  135,  865],
#        [  52, 4482,   26],
#        [ 671,   42, 3764]], dtype=int64)

# %%
# Plot the confusion matrix using seaborn and matplotlib
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['LQ_CLOSE 0', 'LQ_EDIT 1', 'HQ 2'], yticklabels=['LQ_CLOSE 0', 'LQ_EDIT 1', 'HQ 2'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# จากการใช้ word embedding และ LSTM  จะพบว่า model ไม่ทำการ early stop เลยเพราะโอกาสเกิดoverfit ของข้อมูลนั้นค่อนข้างคงที่ไปพร้อมๆกับ loss ของ accuracy ถึงแม้ตอนเริ่มต้น loss จะสูงแต่หลังจากการtrain ไปเรื่อยๆพบว่า model นั้นรักษาระดับค่า validation loss ได้เป็นอย่างดี ถึงจะtrain ไป50 epoch ติดกันก็ตาม แสดงว่า model สามารถทำงานได้อย่างมีประสิทธิภาพมากกว่าmodel อื่นๆก่อนหน้า เพราะทั้ง training และ validation นั้นมีความใกล้เคียงกันอย่างมาก แต่ถึงอย่างไร model ก็สามารถปรับแต่งเพิ่มเติมได้ในอนาคตถ้าหากพบว่ามีจุดที่ต้องปรับปรุงอยู่

# %% [markdown]
# ### เทียบคะแนนกับ model ตัวอื่นๆ
#
# DNN with CountVectorizer (ตัวที่แย่ที่สุด)
#
# Train Accuracy : 0.925
# Validation Accuracy : 0.875
#
#
# DNN with Flattern layers and word embeddings (ตัวที่ดีที่สุด อันดับ3)
#
# Training Accuracy: 0.8716
# Validation Accuracy: 0.8331
#
#
# DNN with GlobalMaxpooling layer and word embeddings (ตัวที่ดีที่สุด อันดับ 2 )
#
# Training Accuracy: 0.8722
# Validation Accuracy: 0.8620
#
#
# DNN with ConVU1d and word embeddings (อันดับ4)
#
# Training Accuracy: 0.8692
# Validation Accuracy: 0.8453
#
# simple RNN with LSTM  (ตัวที่ให้ผลดีที่สุดในตอนนี้ )
#
# Training Accuracy: 0.85
# Validation Accuracy: 0.85
